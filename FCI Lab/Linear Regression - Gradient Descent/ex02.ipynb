# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
import datetime
from helpers import *

height, weight, gender = load_data(sub_sample=False, add_outlier=False)
x, mean_x, std_x = standardize(height)
y, tx = build_model_data(x, weight)

# %%
y.shape, tx.shape
# Out:
# ((10000,), (10000, 2))

# %% [markdown]
# # 1 Computing the Cost Function

# %% [markdown]
# Fill in the `compute_loss` function below:
# <a id='compute_loss'></a>

# %%
def calculate_mse(v):
    """Calculate the mse for vector v."""
    return np.mean(v**2)


def calculate_mae(v):
    """Calculate the mae for vector v."""
    return np.mean(np.abs(v))

def compute_loss(y, tx, w):
    """Calculate the loss.

    You can calculate the loss using mse or mae.
    """
    # ***************************************************
    error = (y - tx.dot(w))
    return (1/(2*tx.shape[0]))*calculate_mse(error)
    #return (1/(2*tx.shape[0]))*calculate_mae(error)
    # ***************************************************
    raise NotImplementedError

# %% [markdown]
# # 2 Grid Search
#
# Fill in the function `grid_search()` below:

# %%
def grid_search(y, tx, w0, w1):
    """Algorithm for grid search."""
    losses = np.zeros((len(w0), len(w1)))
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute loss for each combination of w0 and w1.
    for ind_row, row in enumerate(w0):
        for ind_col, col in enumerate(w1):
            w = np.array([row, col])
            losses[ind_row, ind_col] = compute_loss(y, tx, w)
    return losses
    # ***************************************************
    raise NotImplementedError

# %% [markdown]
# Let us play with the grid search demo now!

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=10)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.004242448314678248, w0*=66.66666666666669, w1*=16.666666666666686, execution time=0.005 seconds

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=20)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.003105802662144846, w0*=73.68421052631578, w1*=7.89473684210526, execution time=0.034 seconds

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=30)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.0020759339381144193, w0*=75.86206896551724, w1*=15.517241379310349, execution time=0.042 seconds

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=40)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.002385549811067054, w0*=76.92307692307693, w1*=11.538461538461547, execution time=0.065 seconds

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=50)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.0018793541019523237, w0*=71.42857142857142, w1*=15.306122448979579, execution time=0.105 seconds

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=100)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.001555870336860953, w0*=72.72727272727272, w1*=13.636363636363626, execution time=0.483 seconds

# %% [markdown]
# # 3 Gradient Descent

# %% [markdown]
# Again, please fill in the functions `compute_gradient` below:

# %%
def compute_gradient(y, tx, w):
    """Compute the gradient."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute gradient and error vector
    error = y - tx.dot(w)
    gradient = -tx.T.dot(error) / len(error)
    return gradient, error
    # ***************************************************
    raise NotImplementedError

# %% [markdown]
# Please fill in the functions `gradient_descent` below:

# %%
def gradient_descent(y, tx, initial_w, max_iters, gamma):
    """Gradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: compute gradient and loss
        gradient, error = compute_gradient(y, tx, w)
        loss = calculate_mse(error)
        # ***************************************************
        #raise NotImplementedError
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: update w by gradient
        w = w - gamma * gradient
        # ***************************************************
        #raise NotImplementedError
        # store w and loss
        ws.append(w)
        losses.append(loss)
        print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))

    return losses, ws

# %% [markdown]
# Test your gradient descent function through gradient descent demo shown below:

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=51.30574540147368, w1=9.435798704492347
# Gradient Descent(1/49): loss=530.6049242179174, w0=66.69746902191575, w1=12.266538315840018
# Gradient Descent(2/49): loss=75.75675910088192, w0=71.31498610804836, w1=13.115760199244335
# Gradient Descent(3/49): loss=34.82042424034888, w0=72.70024123388815, w1=13.370526764265632
# Gradient Descent(4/49): loss=31.136154102900896, w0=73.11581777164008, w1=13.446956733772025
# Gradient Descent(5/49): loss=30.80456979053059, w0=73.24049073296565, w1=13.469885724623941
# Gradient Descent(6/49): loss=30.77472720241726, w0=73.27789262136334, w1=13.476764421879516
# Gradient Descent(7/49): loss=30.77204136948706, w0=73.28911318788263, w1=13.478828031056189
# Gradient Descent(8/49): loss=30.771799644523348, w0=73.29247935783842, w1=13.47944711380919
# Gradient Descent(9/49): loss=30.77177788927661, w0=73.29348920882515, w1=13.47963283863509
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 2.5

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=183.23480500526315, w1=33.69928108747267
# Gradient Descent(1/49): loss=12526.600487744221, w0=-91.61740250263213, w1=-16.84964054373615
# Gradient Descent(2/49): loss=28146.38637775253, w0=320.6609087592112, w1=58.97374190307668
# Gradient Descent(3/49): loss=63290.904630271136, w0=-297.7565581335555, w1=-54.76133176714128
# Gradient Descent(4/49): loss=142366.07069843903, w0=629.8696422055949, w1=115.84127873818468
# Gradient Descent(5/49): loss=320285.19435181434, w0=-761.5696583031303, w1=-140.06263701980188
# Gradient Descent(6/49): loss=720603.2225719108, w0=1325.5892924599607, w1=243.79323661717322
# Gradient Descent(7/49): loss=1621318.7860671321, w0=-1805.1491336846761, w1=-331.9905738382838
# Gradient Descent(8/49): loss=3647928.803931366, w0=2890.958505532291, w1=531.6851418448973
# Gradient Descent(9/49): loss=8207801.344125977, w0=-4153.20295329317, w1=-763.8284316798513
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 2

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=146.58784400421052, w1=26.959424869978136
# Gradient Descent(1/49): loss=5584.473425518357, w0=2.5579538487363607e-13, w1=1.0302869668521453e-13
# Gradient Descent(2/49): loss=5584.473425518295, w0=146.58784400421033, w1=26.959424869978008
# Gradient Descent(3/49): loss=5584.473425518324, w0=4.831690603168681e-13, w1=2.4513724383723456e-13
# Gradient Descent(4/49): loss=5584.4734255182575, w0=146.58784400421013, w1=26.95942486997787
# Gradient Descent(5/49): loss=5584.473425518291, w0=6.252776074688882e-13, w1=4.440892098500626e-13
# Gradient Descent(6/49): loss=5584.473425518231, w0=146.58784400420996, w1=26.95942486997765
# Gradient Descent(7/49): loss=5584.47342551826, w0=8.242295734817162e-13, w1=6.821210263296962e-13
# Gradient Descent(8/49): loss=5584.473425518195, w0=146.58784400420964, w1=26.95942486997741
# Gradient Descent(9/49): loss=5584.473425518208, w0=9.663381206337363e-13, w1=9.450218385609332e-13
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 1

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=73.29392200210526, w1=13.479712434989068
# Gradient Descent(1/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(2/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(3/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(4/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(5/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(6/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(7/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(8/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(9/49): loss=30.7717757376588, w0=73.29392200210519, w1=13.479712434989048
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.5

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=36.64696100105263, w1=6.739856217494534
# Gradient Descent(1/49): loss=1419.197188182825, w0=54.970441501578925, w1=10.109784326241785
# Gradient Descent(2/49): loss=377.8781288489497, w0=64.13218175184208, w1=11.79474838061542
# Gradient Descent(3/49): loss=117.54836401548108, w0=68.71305187697362, w1=12.637230407802226
# Gradient Descent(4/49): loss=52.4659228071145, w0=71.0034869395394, w1=13.058471421395636
# Gradient Descent(5/49): loss=36.19531250502276, w0=72.1487044708223, w1=13.269091928192342
# Gradient Descent(6/49): loss=32.127659929499785, w0=72.72131323646374, w1=13.374402181590694
# Gradient Descent(7/49): loss=31.110746785619046, w0=73.00761761928447, w1=13.427057308289871
# Gradient Descent(8/49): loss=30.856518499648857, w0=73.15076981069484, w1=13.453384871639459
# Gradient Descent(9/49): loss=30.792961428156314, w0=73.22234590640002, w1=13.466548653314254
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.01

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=0.7329392200210526, w1=0.1347971243498907
# Gradient Descent(1/49): loss=5473.954762687698, w0=1.4585490478418934, w1=0.2682462774562816
# Gradient Descent(2/49): loss=5365.6354212473925, w0=2.176902777384528, w1=0.4003609390316091
# Gradient Descent(3/49): loss=5259.471634701749, w0=2.8880729696317315, w1=0.5311544539911822
# Gradient Descent(4/49): loss=5155.420507508365, w0=3.5921314599564615, w1=0.66064003380116
# Gradient Descent(5/49): loss=5053.439997746128, w0=4.2891493653779476, w1=0.788830757813038
# Gradient Descent(6/49): loss=4953.488900128159, w0=4.97919709174522, w1=0.9157395745847982
# Gradient Descent(7/49): loss=4855.526829352789, w0=5.662344340848822, w1=1.0413793031888403
# Gradient Descent(8/49): loss=4759.514203785848, w0=6.3386601174613855, w1=1.1657626345068413
# Gradient Descent(9/49): loss=4665.412229467688, w0=7.008212736307824, w1=1.2889021325116614
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.001

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=0.07329392200210526, w1=0.013479712434989069
# Gradient Descent(1/49): loss=5573.371575920422, w0=0.14651455008220804, w1=0.026945945157542978
# Gradient Descent(2/49): loss=5562.2919189198565, w0=0.21966195753423115, w1=0.04039871164737438
# Gradient Descent(3/49): loss=5551.234410153636, w0=0.29273621757880225, w1=0.053838025370716046
# Gradient Descent(4/49): loss=5540.199005347438, w0=0.36573740336332866, w1=0.06726389978033444
# Gradient Descent(5/49): loss=5529.185660315449, w0=0.4386655879620706, w1=0.08067634831554318
# Gradient Descent(6/49): loss=5518.1943309601775, w0=0.5115208443762137, w1=0.09407538440221652
# Gradient Descent(7/49): loss=5507.224973272288, w0=0.5843032455339429, w1=0.10746102145280301
# Gradient Descent(8/49): loss=5496.277543330415, w0=0.657012864290514, w1=0.12083327286633916
# Gradient Descent(9/49): loss=5485.351997300997, w0=0.7296497734283286, w1=0.13419215202846185
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=5584.473425518335, w0=7.329392200210527, w1=1.3479712434989068
# Gradient Descent(1/49): loss=4529.270112060005, w0=13.925845180399985, w1=2.56114536264793
# Gradient Descent(2/49): loss=3674.5554281587592, w0=19.86265286257052, w1=3.653002069882035
# Gradient Descent(3/49): loss=2982.2365341987493, w0=25.205779776523993, w1=4.635673106392735
# Gradient Descent(4/49): loss=2421.458230091141, w0=30.014593999082106, w1=5.520077039252365
# Gradient Descent(5/49): loss=1967.2278037639803, w0=34.34252679938441, w1=6.316040578826027
# Gradient Descent(6/49): loss=1599.3011584389799, w0=38.23766631965648, w1=7.032407764442323
# Gradient Descent(7/49): loss=1301.2805757257292, w0=41.74329188790136, w1=7.677138231496991
# Gradient Descent(8/49): loss=1059.8839037279956, w0=44.89835489932175, w1=8.257395651846188
# Gradient Descent(9/49): loss=864.352599409831, w0=47.737911609600104, w1=8.779627330160471
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([100, 10])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=756.0947763975176, w0=97.32939220021052, w1=10.347971243498908
# Gradient Descent(1/49): loss=618.2834062721446, w0=94.92584518039999, w1=10.661145362647924
# Gradient Descent(2/49): loss=506.65619647059236, w0=92.7626528625705, w1=10.94300206988204
# Gradient Descent(3/49): loss=416.2381565313348, w0=90.81577977652397, w1=11.196673106392742
# Gradient Descent(4/49): loss=342.9995441805362, w0=89.06359399908209, w1=11.424977039252374
# Gradient Descent(5/49): loss=283.6762681763894, w0=87.4866267993844, w1=11.630450578826043
# Gradient Descent(6/49): loss=235.62441461303052, w0=86.06735631965648, w1=11.815376764442345
# Gradient Descent(7/49): loss=196.7024132267101, w0=84.79001288790136, w1=11.981810331497018
# Gradient Descent(8/49): loss=165.17559210379036, w0=83.64040379932173, w1=12.131600541846222
# Gradient Descent(9/49): loss=139.63886699422522, w0=82.60575561960007, w1=12.266411731160506
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([1000, -1000])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=1885956.0542912884, w0=907.3293922002102, w1=-898.6520287565011
# Gradient Descent(1/49): loss=1527630.2506133334, w0=823.9258451803995, w1=-807.4388546373519
# Gradient Descent(2/49): loss=1237386.3496341896, w0=748.8626528625699, w1=-725.3469979301176
# Gradient Descent(3/49): loss=1002288.7898410831, w0=681.3057797765233, w1=-651.4643268936069
# Gradient Descent(4/49): loss=811859.7664086672, w0=620.5045939990814, w1=-584.9699229607471
# Gradient Descent(5/49): loss=657612.2574284103, w0=565.7835267993837, w1=-525.1249594211733
# Gradient Descent(6/49): loss=532671.7751544024, w0=516.5345663196557, w1=-471.264492235557
# Gradient Descent(7/49): loss=431469.98451245576, w0=472.2105018879006, w1=-422.7900717685023
# Gradient Descent(8/49): loss=349496.53409247915, w0=432.31884389932105, w1=-379.16309334815315
# Gradient Descent(9/49): loss=283098.03925229824, w0=396.4163517095993, w1=-339.89881276983897
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 4 Stochastic gradient descent

# %%
def compute_stoch_gradient(y, tx, w):
    """Compute a stochastic gradient from just few examples n and their corresponding y_n labels."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: implement stochastic gradient computation.It's same as the gradient descent.
    error = y - tx.dot(w)
    gradient = -tx.T.dot(error) / len(error)
    return gradient, error
    # ***************************************************
    raise NotImplementedError


def stochastic_gradient_descent(
        y, tx, initial_w, batch_size, max_iters, gamma):
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w

    """Stochastic gradient descent algorithm."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: implement stochastic gradient descent.
    for n_iter in range(max_iters):
        for y_batch, tx_batch in batch_iter(y, tx, batch_size=batch_size, num_batches=1):
            # compute a stochastic gradient and loss
            grad, _ = compute_stoch_gradient(y_batch, tx_batch, w)
            # update w through the stochastic gradient update
            w = w - gamma * grad
            # calculate loss
            loss = compute_loss(y, tx, w)
            # store w and loss
            ws.append(w)
            losses.append(loss)
            print("Stochastic Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
    return losses, ws
    # ***************************************************
    raise NotImplementedError

# %%
# from stochastic_gradient_descent import *

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time = datetime.datetime.now()
sgd_losses, sgd_ws = stochastic_gradient_descent(
    y, tx, w_initial, batch_size, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Stochastic Gradient Descent(0/49): loss=0.11258196448903944, w0=41.608569409096646, w1=-21.404466573550895
# Stochastic Gradient Descent(1/49): loss=0.03528636614026398, w0=73.22220834562935, w1=-12.50009518976244
# Stochastic Gradient Descent(2/49): loss=0.022837884574468215, w0=59.41598197263744, w1=-1.797351952196161
# Stochastic Gradient Descent(3/49): loss=0.0031705563552583975, w0=78.34613671664533, w1=10.812414580287932
# Stochastic Gradient Descent(4/49): loss=0.007982507715582784, w0=67.40614160969233, w1=3.773404144773062
# Stochastic Gradient Descent(5/49): loss=0.007849368369142079, w0=67.55059723145625, w1=3.824153817071946
# Stochastic Gradient Descent(6/49): loss=0.008967675785755958, w0=62.5614291474428, w1=7.700842553941261
# Stochastic Gradient Descent(7/49): loss=0.009046157770999182, w0=62.181351150679234, w1=8.31617210355334
# Stochastic Gradient Descent(8/49): loss=0.010764148781919483, w0=75.10816701993252, w1=26.94149964605503
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact
def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses, sgd_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 5 Effect of Outliers

# %% [markdown]
# ### Exercise 5

# %%
height_ol, weight_ol, gender_ol = load_data(sub_sample=False, add_outlier=True)
x_ol, mean_x_ol, std_x_ol = standardize(height_ol)
y_ol, tx_ol = build_model_data(x_ol, weight_ol)

# %% [markdown]
# #### Grid Search

# %%
# Generate the grid of parameters to be swept
grid_w0_ol, grid_w1_ol = generate_w(num_intervals=10)

# Start the grid search
start_time_ol = datetime.datetime.now()
grid_losses_ol = grid_search(y_ol, tx_ol, grid_w0_ol, grid_w1_ol)

# Select the best combinaison
loss_star_ol, w0_star_ol, w1_star_ol = get_best_parameters(grid_w0_ol, grid_w1_ol, grid_losses_ol)
end_time_ol = datetime.datetime.now()
execution_time_ol = (end_time_ol - start_time_ol).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star_ol, w0=w0_star_ol, w1=w1_star_ol, t=execution_time_ol))

# Plot the results
fig = grid_visualization(grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.004407921139598234, w0*=66.66666666666669, w1*=16.666666666666686, execution time=0.008 seconds

# %%
# Generate the grid of parameters to be swept
grid_w0_ol, grid_w1_ol = generate_w(num_intervals=20)

# Start the grid search
start_time_ol = datetime.datetime.now()
grid_losses_ol = grid_search(y_ol, tx_ol, grid_w0_ol, grid_w1_ol)

# Select the best combinaison
loss_star_ol, w0_star_ol, w1_star_ol = get_best_parameters(grid_w0_ol, grid_w1_ol, grid_losses_ol)
end_time_ol = datetime.datetime.now()
execution_time_ol = (end_time_ol - start_time_ol).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star_ol, w0=w0_star_ol, w1=w1_star_ol, t=execution_time_ol))

# Plot the results
fig = grid_visualization(grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.003190149268448888, w0*=73.68421052631578, w1*=7.89473684210526, execution time=0.037 seconds

# %%
# Generate the grid of parameters to be swept
grid_w0_ol, grid_w1_ol = generate_w(num_intervals=30)

# Start the grid search
start_time_ol = datetime.datetime.now()
grid_losses_ol = grid_search(y_ol, tx_ol, grid_w0_ol, grid_w1_ol)

# Select the best combinaison
loss_star_ol, w0_star_ol, w1_star_ol = get_best_parameters(grid_w0_ol, grid_w1_ol, grid_losses_ol)
end_time_ol = datetime.datetime.now()
execution_time_ol = (end_time_ol - start_time_ol).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star_ol, w0=w0_star_ol, w1=w1_star_ol, t=execution_time_ol))

# Plot the results
fig = grid_visualization(grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.0022238458793304517, w0*=75.86206896551724, w1*=15.517241379310349, execution time=0.179 seconds

# %%
# Generate the grid of parameters to be swept
grid_w0_ol, grid_w1_ol = generate_w(num_intervals=40)

# Start the grid search
start_time_ol = datetime.datetime.now()
grid_losses_ol = grid_search(y_ol, tx_ol, grid_w0_ol, grid_w1_ol)

# Select the best combinaison
loss_star_ol, w0_star_ol, w1_star_ol = get_best_parameters(grid_w0_ol, grid_w1_ol, grid_losses_ol)
end_time_ol = datetime.datetime.now()
execution_time_ol = (end_time_ol - start_time_ol).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star_ol, w0=w0_star_ol, w1=w1_star_ol, t=execution_time_ol))

# Plot the results
fig = grid_visualization(grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.0024983799557433605, w0*=76.92307692307693, w1*=11.538461538461547, execution time=0.188 seconds

# %%
# Generate the grid of parameters to be swept
grid_w0_ol, grid_w1_ol = generate_w(num_intervals=50)

# Start the grid search
start_time_ol = datetime.datetime.now()
grid_losses_ol = grid_search(y_ol, tx_ol, grid_w0_ol, grid_w1_ol)

# Select the best combinaison
loss_star_ol, w0_star_ol, w1_star_ol = get_best_parameters(grid_w0_ol, grid_w1_ol, grid_losses_ol)
end_time_ol = datetime.datetime.now()
execution_time_ol = (end_time_ol - start_time_ol).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star_ol, w0=w0_star_ol, w1=w1_star_ol, t=execution_time_ol))

# Plot the results
fig = grid_visualization(grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.002029425965302139, w0*=71.42857142857142, w1*=15.306122448979579, execution time=0.216 seconds

# %%
# Generate the grid of parameters to be swept
grid_w0_ol, grid_w1_ol = generate_w(num_intervals=100)

# Start the grid search
start_time_ol = datetime.datetime.now()
grid_losses_ol = grid_search(y_ol, tx_ol, grid_w0_ol, grid_w1_ol)

# Select the best combinaison
loss_star_ol, w0_star_ol, w1_star_ol = get_best_parameters(grid_w0_ol, grid_w1_ol, grid_losses_ol)
end_time_ol = datetime.datetime.now()
execution_time_ol = (end_time_ol - start_time_ol).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star_ol, w0=w0_star_ol, w1=w1_star_ol, t=execution_time_ol))

# Plot the results
fig = grid_visualization(grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=0.0016905539238492788, w0*=72.72727272727272, w1*=13.636363636363626, execution time=0.973 seconds

# %% [markdown]
# #### Gradient Descent

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=51.311949971831744, w1=9.375829281932607
# Gradient Descent(1/49): loss=533.1707926574862, w0=66.70553496338121, w1=12.188578066512388
# Gradient Descent(2/49): loss=78.40476551123557, w0=71.32361046084606, w1=13.032402701886323
# Gradient Descent(3/49): loss=37.475823068073076, w0=72.70903311008549, w1=13.285550092498507
# Gradient Descent(4/49): loss=33.792218248188505, w0=73.12465990485732, w1=13.361494309682163
# Gradient Descent(5/49): loss=33.46069381439888, w0=73.24934794328887, w1=13.384277574837261
# Gradient Descent(6/49): loss=33.43085661535781, w0=73.28675435481834, w1=13.39111255438379
# Gradient Descent(7/49): loss=33.428171267444114, w0=73.29797627827718, w1=13.393163048247748
# Gradient Descent(8/49): loss=33.42792958613189, w0=73.30134285531483, w1=13.393778196406936
# Gradient Descent(9/49): loss=33.427907834813794, w0=73.30235282842612, w1=13.393962740854693
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 2.5

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=183.2569641851134, w1=33.48510457833074
# Gradient Descent(1/49): loss=12527.00008003125, w0=-91.62848209255637, w1=-16.742552289165353
# Gradient Descent(2/49): loss=28143.96529796564, w0=320.69968732394784, w1=58.598933012078795
# Gradient Descent(3/49): loss=63282.137038318295, w0=-297.79256680080834, w1=-54.413294939787086
# Gradient Descent(4/49): loss=142343.0234541114, w0=629.9458143863246, w1=115.10504698801006
# Gradient Descent(5/49): loss=320230.0178896448, w0=-761.6617573943729, w1=-139.17246590368646
# Gradient Descent(6/49): loss=720475.7553695954, w0=1325.749600276675, w1=242.24380343385846
# Gradient Descent(7/49): loss=1621028.6646994904, w0=-1805.3674362299005, w1=-329.88060057245957
# Gradient Descent(8/49): loss=3647272.710691755, w0=2891.308118529956, w1=528.306005437019
# Gradient Descent(9/49): loss=8206321.8141743, w0=-4153.705213609813, w1=-758.9739035771973
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 2

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=146.6055713480907, w1=26.788083662664594
# Gradient Descent(1/49): loss=5586.126649838107, w0=2.8421709430404007e-13, w1=2.0605739337042905e-13
# Gradient Descent(2/49): loss=5586.12664983803, w0=146.60557134809048, w1=26.788083662664448
# Gradient Descent(3/49): loss=5586.126649838069, w0=5.115907697472721e-13, w1=3.055333763768431e-13
# Gradient Descent(4/49): loss=5586.1266498379955, w0=146.60557134809025, w1=26.788083662664338
# Gradient Descent(5/49): loss=5586.126649838032, w0=7.105427357601002e-13, w1=3.694822225952521e-13
# Gradient Descent(6/49): loss=5586.126649837964, w0=146.60557134809008, w1=26.788083662664253
# Gradient Descent(7/49): loss=5586.126649838005, w0=8.242295734817162e-13, w1=5.222489107836736e-13
# Gradient Descent(8/49): loss=5586.126649837944, w0=146.6055713480899, w1=26.788083662664068
# Gradient Descent(9/49): loss=5586.1266498379755, w0=9.947598300641403e-13, w1=6.110667527536862e-13
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 1

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=73.30278567404535, w1=13.394041831332297
# Gradient Descent(1/49): loss=33.42790568358452, w0=73.30278567404525, w1=13.394041831332302
# Gradient Descent(2/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(3/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(4/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(5/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(6/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(7/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(8/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# Gradient Descent(9/49): loss=33.42790568358452, w0=73.30278567404527, w1=13.394041831332302
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.5

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=36.65139283702268, w1=6.697020915666148
# Gradient Descent(1/49): loss=1421.6025917222044, w0=54.977089255533926, w1=10.045531373499234
# Gradient Descent(2/49): loss=380.4715771932409, w0=64.13993746478958, w1=11.719786602415759
# Gradient Descent(3/49): loss=120.18882356099884, w0=68.72136156941743, w1=12.556914216874032
# Gradient Descent(4/49): loss=55.118135152938045, w0=71.01207362173133, w1=12.975478024103165
# Gradient Descent(5/49): loss=38.85046305092295, w0=72.15742964788829, w1=13.184759927717733
# Gradient Descent(6/49): loss=34.78354502541914, w0=72.73010766096678, w1=13.289400879525017
# Gradient Descent(7/49): loss=33.76681551904317, w0=73.01644666750602, w1=13.34172135542866
# Gradient Descent(8/49): loss=33.51263314244919, w0=73.15961617077564, w1=13.367881593380481
# Gradient Descent(9/49): loss=33.449087548300696, w0=73.23120092241045, w1=13.380961712356392
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.01

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=0.7330278567404536, w1=0.13394041831332298
# Gradient Descent(1/49): loss=5475.6279448294035, w0=1.4587254349134988, w1=0.2665414324435117
# Gradient Descent(2/49): loss=5367.328164050403, w0=2.1771660373048145, w1=0.397816436432399
# Gradient Descent(3/49): loss=5261.1835489089035, w0=2.888422233672219, w1=0.5277786903813989
# Gradient Descent(4/49): loss=5157.151211608719, w0=3.5925658680759476, w1=0.6564413217909072
# Gradient Descent(5/49): loss=5055.18911782081, w0=4.289668066135643, w1=0.7838173268863207
# Gradient Descent(6/49): loss=4955.256069699278, w0=4.979799242214739, w1=0.90991957193078
# Gradient Descent(7/49): loss=4857.3116892353655, w0=5.663029106533043, w1=1.0347607945247952
# Gradient Descent(8/49): loss=4761.316401942686, w0=6.339426672208166, w1=1.1583536048928702
# Gradient Descent(9/49): loss=4667.2314208671305, w0=7.009060262226538, w1=1.2807104871572645
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.001

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=0.07330278567404536, w1=0.013394041831332297
# Gradient Descent(1/49): loss=5575.026805048514, w0=0.14653226856241686, w1=0.02677468962083327
# Gradient Descent(2/49): loss=5563.949148848683, w0=0.21968852196789956, w1=0.04014195676254473
# Gradient Descent(3/49): loss=5552.893636883596, w0=0.2927716191199773, w1=0.05349585663711451
# Gradient Descent(4/49): loss=5541.860224886927, w0=0.36578163317490286, w1=0.06683640261180968
# Gradient Descent(5/49): loss=5530.848868680839, w0=0.4387186372157732, w1=0.08016360804053017
# Gradient Descent(6/49): loss=5519.859524175808, w0=0.511582704252603, w1=0.0934774862638221
# Gradient Descent(7/49): loss=5508.892147370442, w0=0.5843739072223957, w1=0.10677805060889069
# Gradient Descent(8/49): loss=5497.94669435131, w0=0.6570923189892185, w1=0.1200653143896141
# Gradient Descent(9/49): loss=5487.023121292764, w0=0.7297380123442747, w1=0.13333929090655677
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=5586.126649838079, w0=7.330278567404536, w1=1.3394041831332297
# Gradient Descent(1/49): loss=4531.113888448723, w0=13.927529278068628, w1=2.544867947953133
# Gradient Descent(2/49): loss=3676.5535517233443, w0=19.865054917666292, w1=3.6297853362910564
# Gradient Descent(3/49): loss=2984.3596789757903, w0=25.20882799330419, w1=4.60621098579518
# Gradient Descent(4/49): loss=2423.6826420502707, w0=30.01822376137829, w1=5.484994070348893
# Gradient Descent(5/49): loss=1969.5342421406008, w0=34.346679952644976, w1=6.275898846447237
# Gradient Descent(6/49): loss=1601.6740382137689, w0=38.24229052478501, w1=6.987713144935749
# Gradient Descent(7/49): loss=1303.7072730330328, w0=41.74834003971104, w1=7.628346013575401
# Gradient Descent(8/49): loss=1062.3541932366377, w0=44.903784603144466, w1=8.204915595351089
# Gradient Descent(9/49): loss=866.8581986015573, w0=47.74368471023454, w1=8.723828218949212
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([100, 10])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=757.6886784023812, w0=97.33027856740452, w1=10.339404183133231
# Gradient Descent(1/49): loss=620.0791315858096, w0=94.9275292780686, w1=10.64486794795314
# Gradient Descent(2/49): loss=508.6153986643873, w0=92.76505491766628, w1=10.919785336291058
# Gradient Descent(3/49): loss=418.329774998035, w0=90.81882799330417, w1=11.167210985795185
# Gradient Descent(4/49): loss=345.19841982828916, w0=89.06722376137827, w1=11.389894070348896
# Gradient Descent(5/49): loss=285.96202214079517, w0=87.49077995264497, w1=11.590308846447238
# Gradient Descent(6/49): loss=237.98054001392512, w0=86.071980524785, w1=11.770682144935744
# Gradient Descent(7/49): loss=199.11553949116052, w0=84.79506103971103, w1=11.9330181135754
# Gradient Descent(8/49): loss=167.6348890677211, w0=83.64583350314446, w1=12.07912048535109
# Gradient Descent(9/49): loss=142.13556222473528, w0=82.61152872023455, w1=12.210612619949211
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([1000, -1000])

# Start gradient descent.
start_time_ol = datetime.datetime.now()
gradient_losses_ol, gradient_ws_ol = gradient_descent(y_ol, tx_ol, w_initial, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Gradient Descent(0/49): loss=1885768.6389644123, w0=907.3302785674043, w1=-898.6605958168668
# Gradient Descent(1/49): loss=1527478.9488632537, w0=823.9275292780684, w1=-807.455132052047
# Gradient Descent(2/49): loss=1237264.2998813156, w0=748.865054917666, w1=-725.3702146637092
# Gradient Descent(3/49): loss=1002190.4342059458, w0=681.3088279933039, w1=-651.4937890142053
# Gradient Descent(4/49): loss=811780.603008896, w0=620.5082237613783, w1=-585.0050059296514
# Gradient Descent(5/49): loss=657548.6397392857, w0=565.787679952645, w1=-525.165101153553
# Gradient Descent(6/49): loss=532620.7494909014, w0=516.539190524785, w1=-471.30918685506447
# Gradient Descent(7/49): loss=431429.15838970995, w0=472.215550039711, w1=-422.83886398642494
# Gradient Descent(8/49): loss=349463.96959774505, w0=432.32427360314443, w1=-379.21557340464926
# Gradient Descent(9/49): loss=283072.16667625343, w0=396.4221248102345, w1=-339.9546118810511
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses_ol, gradient_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# #### Stochastic gradient descent

# %%
# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time_ol = datetime.datetime.now()
sgd_losses_ol, sgd_ws_ol = stochastic_gradient_descent(
    y_ol, tx_ol, w_initial, batch_size, max_iters, gamma)
end_time_ol = datetime.datetime.now()

# Print result
exection_time_ol = (end_time_ol - start_time_ol).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=exection_time_ol))
# Out:
# Stochastic Gradient Descent(0/49): loss=0.013286299234597319, w0=59.408031974285485, w1=19.661979596523686
# Stochastic Gradient Descent(1/49): loss=0.003375161419824362, w0=69.80990994428075, w1=18.072571781541455
# Stochastic Gradient Descent(2/49): loss=0.003496696109790185, w0=67.48941051952531, w1=15.044700066542877
# Stochastic Gradient Descent(3/49): loss=0.0026616178556940254, w0=70.63444847788244, w1=9.831027025119347
# Stochastic Gradient Descent(4/49): loss=0.002785898524688345, w0=72.926015635877, w1=8.68668028343524
# Stochastic Gradient Descent(5/49): loss=0.0022417070199951305, w0=76.16726264991746, w1=11.602402024033944
# Stochastic Gradient Descent(6/49): loss=0.004707240605730097, w0=65.96432281340778, w1=10.770552125523508
# Stochastic Gradient Descent(7/49): loss=0.0038167355156643774, w0=67.83299629134011, w1=9.7880085979009
# Stochastic Gradient Descent(8/49): loss=0.005885984178644714, w0=81.75609080681362, w1=16.97970134644754
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact
def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses_ol, sgd_ws_ol, grid_losses_ol, grid_w0_ol, grid_w1_ol, mean_x_ol, std_x_ol, height_ol, weight_ol, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(sgd_ws_ol)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 6 Subgradient Descent

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Modify the function `compute_loss(y, tx, w)` for the Mean Absolute Error cost function [here](#compute_loss)

# %%
def compute_subgradient(y, tx, w):
    """Compute the subgradient."""
    err = y - tx.dot(w)
    grad = -np.dot(tx.T,np.sign(err)) / len(err)
    return grad, err

# %%
def subgradient_descent(y, tx, initial_w, max_iters, gamma):
    """SubGradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        # compute loss, gradient
        gradient, error = compute_subgradient(y, tx, w)
        loss = calculate_mae(error)
        # gradient w by descent update
        w = w - gamma * gradient
        # store w and loss
        ws.append(w)
        losses.append(loss)
        print("Sub Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))

    return losses, ws

# %%
# Define the parameters of the algorithm.
max_iters = 500
gamma = 0.7
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time = datetime.datetime.now()
sgd_losses, sgd_ws = subgradient_descent(
    y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Sub Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Sub Gradient Descent(0/499): loss=73.29392200210518, w0=0.7, w1=4.98390217984479e-17
# Sub Gradient Descent(1/499): loss=72.59392200210517, w0=1.4, w1=9.96780435968958e-17
# Sub Gradient Descent(2/499): loss=71.89392200210517, w0=2.0999999999999996, w1=1.495170653953437e-16
# Sub Gradient Descent(3/499): loss=71.19392200210518, w0=2.8, w1=1.993560871937916e-16
# Sub Gradient Descent(4/499): loss=70.49392200210518, w0=3.5, w1=2.491951089922395e-16
# Sub Gradient Descent(5/499): loss=69.79392200210518, w0=4.2, w1=2.990341307906874e-16
# Sub Gradient Descent(6/499): loss=69.09392200210517, w0=4.9, w1=3.4887315258913533e-16
# Sub Gradient Descent(7/499): loss=68.39392200210517, w0=5.6000000000000005, w1=3.9871217438758325e-16
# Sub Gradient Descent(8/499): loss=67.69392200210518, w0=6.300000000000001, w1=4.485511961860311e-16
# Sub Gradient Descent(9/499): loss=66.99392200210517, w0=7.000000000000001, w1=4.98390217984479e-16
# ...

# %%
from ipywidgets import IntSlider, interact
def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses, sgd_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(sgd_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=501, min=1), Output()), _dom_classes=('widg…
# <function __main__.plot_figure(n_iter)>

# %%
def stochastic_subgradient_descent(
        y, tx, initial_w, batch_size, max_iters, gamma):
    """Stochastic gradient descent."""
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w

    for n_iter in range(max_iters):
        for y_batch, tx_batch in batch_iter(y, tx, batch_size=batch_size, num_batches=1):
            # compute a stochastic gradient and loss
            gradient, error = compute_subgradient(y_batch, tx_batch, w)
            # update w through the stochastic gradient update
            w = w - gamma * gradient
            # calculate loss
            loss = calculate_mae(error)
            # store w and loss
            ws.append(w)
            losses.append(loss)

        print("Stochastic Subgradient Descent ({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
    return losses, ws

# %%
# from stochastic_gradient_descent import *

# Define the parameters of the algorithm.
max_iters = 500
gamma = 0.7
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time = datetime.datetime.now()
sgd_losses, sgd_ws = stochastic_subgradient_descent(
    y, tx, w_initial, batch_size, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Stochastic Subgradient Descent : execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Stochastic Subgradient Descent (0/499): loss=69.20364585256478, w0=0.7, w1=0.4729341988980556
# Stochastic Subgradient Descent (1/499): loss=97.09326055514214, w0=1.4, w1=1.7057178418440189
# Stochastic Subgradient Descent (2/499): loss=79.39566084542246, w0=2.0999999999999996, w1=2.312333608597269
# Stochastic Subgradient Descent (3/499): loss=69.61477404856696, w0=2.8, w1=2.6401437553519447
# Stochastic Subgradient Descent (4/499): loss=69.71473701380874, w0=3.5, w1=2.6874838738323326
# Stochastic Subgradient Descent (5/499): loss=58.97805303027203, w0=4.2, w1=2.0969477730088903
# Stochastic Subgradient Descent (6/499): loss=68.09136508473753, w0=4.9, w1=1.4977089943325292
# Stochastic Subgradient Descent (7/499): loss=49.324439900498085, w0=5.6000000000000005, w1=0.5119362641137012
# Stochastic Subgradient Descent (8/499): loss=89.93633734882602, w0=6.300000000000001, w1=1.2239931089130611
# ...

# %%
from ipywidgets import IntSlider, interact
def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses, sgd_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(sgd_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=501, min=1), Output()), _dom_classes=('widg…
# <function __main__.plot_figure(n_iter)>
